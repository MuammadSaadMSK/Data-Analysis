# %% [markdown]
# # PAKISTANI POPULATION ANALYSIS

# %% [markdown]
# **AUTHOR NAME** : MUHAMMAD SAAD\
# **EMAIL** : saadramzankumar1122@gmail.com

# %% [markdown]
# The Data was collected from the following[linl](https://www.kaggle.com/datasets/mabdullahsajid/population-of-pakistan-dataset):
# Years of Data:
# 1. 2017
# 2. 1998

# %% [markdown]
# ## *The dataset collected from the source has following description*
# Description:
# This dataset contains demographic information from the Pakistan Population Census conducted in 2017. It provides detailed population data at various administrative levels within Pakistan, including provinces, divisions, districts, and sub-divisions. The dataset also includes information on urban and rural populations, gender distribution, transgender individuals, sex ratios, population figures from the 1998 census, and annual growth rates.
#
# Features:
# Province: The administrative provinces or regions of Pakistan where the census data was collected.
#
# Division: The divisions within each province. Divisions are the second level of administrative divisions in Pakistan.
#
# District: Districts within each division, representing larger administrative units.
#
# Sub-Division: Sub-divisions or tehsils within each district, providing more localized data.
#
# Area: The land area (in square kilometers) of each sub-division.
#
# Urban Population 2017: The population of urban areas within each sub-division for the year 2017.
#
# Rural Population 2017: The population of rural areas within each sub-division for the year 2017.
#
# Male Population 2017: The male population within each sub-division for the year 2017.
#
# Female Population 2017: The female population within each sub-division for the year 2017.
#
# Transgender Population 2017: The population of transgender individuals within each sub-division for the year 2017.
#
# Sex Ratio 2017: The sex ratio, calculated as the number of females per 1000 males, within each sub-division for the year 2017.
#
# Population in 1998: The total population of each sub-division as recorded in the 1998 census.
#
# Annual Growth Rate: The annual growth rate of the population in each sub-division, calculated as the percentage increase from 1998 to 2017.
#
# Data Source:
# The data in this dataset was collected from official Pakistan Population Census reports and may include data from various government sources. It is essential to provide proper attribution and reference the original sources when using this dataset for analysis or research.
#
# Data Usage:
# Researchers and analysts can use this dataset to explore demographic trends, population growth, urbanization rates, gender distribution, and more within Pakistan at different administrative levels. Ensure compliance with ethical and legal guidelines when using this data for research or public sharing.
#
# Please note that this description is a template, and you should adapt it based on the actual data sources and specific details of your dataset when creating it for Kaggle or any other platform.

# %% [markdown]
# ## Purpose of this analysis:
#
# We will fill this at the end or during the process

# %%
 # import the libraries#
import pandas as pd 
import numpy as np 
import matplotlib as mtb 
import seaborn as sea

# %%
df = pd.read_csv('C:\\Users\\DELL\\Desktop\\kashti.csv')

# %% [markdown]
# # EXPLORE THE DATA (COMPOSITION DATA)

# %%
#OUTLIERS
# Load the data
kashti = pd.read_csv('kashti.csv')

# Display the first few rows of the dataset
print(kashti.head())

# Calculate the IQR for the 'age' column
Q1 = kashti['age'].quantile(0.25)
Q3 = kashti['age'].quantile(0.75)
IQR = Q3 - Q1
print(f"The IQR for the 'age' column is: {IQR}")
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True
# The IQR for the 'age' column is: 17.875

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          714 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     889 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  adult_male   891 non-null    bool
#  12  deck         203 non-null    object
#  13  embark_town  889 non-null    object
#  14  alive        891 non-null    object
#  15  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(5), object(7)
# memory usage: 99.3+ KB

# %%
df.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
# MAXIMUM COLUM PRINTING OPTION
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
# LETS SEE ALL COLUMN NAME ONCE
df.columns
# Out:
# Index(['Unnamed: 0', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# LETS HAVE A LOOK ON DTTYPES
df.dtypes #we already haveseen this in info column as well
# Out:
# Unnamed: 0       int64
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
# summary stastics
df.describe().T
# Out:
#             count        mean         std   min       25%       50%    75%  \
# Unnamed: 0  891.0  445.000000  257.353842  0.00  222.5000  445.0000  667.5
# survived    891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# pclass      891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# age         714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# sibsp       891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# parch       891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# fare        891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                  max
# Unnamed: 0  890.0000
# survived      1.0000
# pclass        3.0000
# age          80.0000
# sibsp         8.0000
# parch         6.0000
# fare        512.3292

# %%
len(df) #number of total values in a column
# Out:
# 891

# %%
# how much are te missing values
df.isnull().sum() # count the missing values
df.isnull().sum() / len(df) * 100
# Out:
# Unnamed: 0      0.000000
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.isnull().sum() # count the missing values
#df.insull().sum() / len(df) * 100  # percentage of missing values in a column
# Out:
# Unnamed: 0       0
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sea.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
df['sex'] # TO SELECT ONE COLUMN
df[['sex','age']] # TO SELECT TWO COLUMNS
df[['sex','age','fare']] # TO SELECT THREE COLUMNS
# Out:
#         sex   age     fare
# 0      male  22.0   7.2500
# 1    female  38.0  71.2833
# 2    female  26.0   7.9250
# 3    female  35.0  53.1000
# 4      male  35.0   8.0500
# ..      ...   ...      ...
# 886    male  27.0  13.0000
# 887  female  19.0  30.0000
# 888  female   NaN  23.4500
# 889    male  26.0  30.0000
# 890    male  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
df['sex'].unique() #   ALL sex me jitne b hai SAB SHOW HU JAY GE
df.sex.unique()  #    ALL sex me jitne b hai SAB SHOW HU JAY GE
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.nunique() # ALL COLUMNS ME JITNE B NAMES HAI SB KI VALUES BTA DE GA
# Out:
# Unnamed: 0     891
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df.columns # ALL COLUMNS NAME BTAYE GA
# Out:
# Index(['Unnamed: 0', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.dtypes # all columns ko list kr de ga
# Out:
# Unnamed: 0       int64
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
df['embark_town'].nunique() # NUMBER OF town me jitne b city hai sb ki values bta de ga
# Out:
# 3

# %%
df['embark_town'].value_counts() # embark town ki VALUE btaye ga
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
# SUMMARY
df.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
df.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
# FIND MEAN FARS OF BOTH MALES AND FEMALES USING GROUPBY FUNCTION
df.groupby('survived')['fare'].mean()  # pore data me jitne b values hai sb bta dee ga calculas kr ke
# Out:
# survived
# 0    22.117887
# 1    48.395408
# Name: fare, dtype: float64

# %%
# group ki value count
df.groupby(['survived','who'])['fare'].value_counts()
# Out:
# survived  who    fare
# 0         child  31.2750     5
#                  27.9000     4
#                  29.1250     4
#                  39.6875     4
#                  46.9000     4
#                             ..
# 1         woman  120.0000    1
#                  133.6500    1
#                  151.5500    1
#                  247.5208    1
#                  512.3292    1
# Name: count, Length: 425, dtype: int64

# %%
# group ka size
df.groupby(['survived','who'])['fare'].size()
# Out:
# survived  who
# 0         child     34
#           man      449
#           woman     66
# 1         child     49
#           man       88
#           woman    205
# Name: fare, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          714 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     889 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  adult_male   891 non-null    bool
#  12  deck         203 non-null    object
#  13  embark_town  889 non-null    object
#  14  alive        891 non-null    object
#  15  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(5), object(7)
# memory usage: 99.3+ KB

# %%
 # correlection method
correlection_df=df[['fare','age','sibsp','parch']].corr()

# %%
sea.heatmap(correlection_df , annot=True)
# Out:
# <Axes: >

# %%
sea.pairplot(df)  # PLOTING THE GRAPH
# Out:
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_stats\counting.py:137: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   bin_edges = np.histogram_bin_edges(vals, bins, binrange, weight)
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_stats\counting.py:176: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   hist, edges = np.histogram(vals, **bin_kws, weights=weights, density=density)
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_stats\counting.py:137: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   bin_edges = np.histogram_bin_edges(vals, bins, binrange, weight)
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_stats\counting.py:176: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   hist, edges = np.histogram(vals, **bin_kws, weights=weights, density=density)

# %% [markdown]
# MAZEED PANDAS KI TIPS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mtb
import seaborn as sea

# %%
# DATA IMPRT
df=sea.load_dataset('titanic')

# %%
# CHEACK THE DATA
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Missing the value and imputing them
# FIND OUT PERCENTAGE MISING VALUES
df.isnull().sum() / len(df) * 100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# DROP THE COLUMN FROM DATASET COLUMN REMOVE KRNA
df.drop ('deck',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
df['age'].mean()  # AGE ke column ki sb average btaye ga
# Out:
# 29.69911764705882

# %%
df['age'].median()  # median kisi pore dataset ka center hota hai
# Out:
# 28.0

# %%
df['age'].mode()[0] # jo REPATATIVE VALUES hoti hai
# Out:
# 24.0

# %%
# Filling the missing values of age column by the mean of age column
df['age'].fillna(df['age'].mean(),inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8292\3295655408.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(),inplace=True)

# %%
df['age'].fillna(df['age'].median(),inplace=True)  # MEDIAN
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8292\1582139354.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(),inplace=True)  # MEDIAN

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
# FILL embark and embark_TOWN with MODE use
df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)
df['embark_town'].fillna(df['embark_town'].mode()[0],inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8292\4281535126.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8292\4281535126.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embark_town'].fillna(df['embark_town'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
sea.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # BINNING

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
df.age.min()
# Out:
# 0.42

# %%
df.age.max()
# Out:
# 80.0

# %%
sea.histplot(df['age'])  # GRAPH
# Out:
# c:\Users\DELL\.conda\envs\python_eda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='Count'>

# %%
# BILLING of AGE column into 7 categories
bins=[0,1,5,12,18,30,50,80]
lables=['infants','Tollders','Kids','Teens','Youngs','Middle Age','Old']

# KIS COLUMN KO BINS me convert krna hai
pd.cut(df['age'],bins=bins,labels=lables)
# Out:
# 0          Youngs
# 1      Middle Age
# 2          Youngs
# 3      Middle Age
# 4      Middle Age
#           ...
# 886        Youngs
# 887        Youngs
# 888        Youngs
# 889        Youngs
# 890    Middle Age
# Name: age, Length: 891, dtype: category
# Categories (7, object): ['infants' < 'Tollders' < 'Kids' < 'Teens' < 'Youngs' < 'Middle Age' < 'Old']

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %% [markdown]
# # FEATURE Engeeneering

# %%
bins=[0,1,5,12,18,30,50,80]
lables=['infants','Tollders','Kids','Teens','Youngs','Middle Age','Old']

# KIS COLUMN KO BINS me convert krna hai
df['binned_age'] = pd.cut(df['age'], bins=bins, labels=lables)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone  binned_age
# 0    man        True  Southampton    no  False      Youngs
# 1  woman       False    Cherbourg   yes  False  Middle Age
# 2  woman       False  Southampton   yes   True      Youngs
# 3  woman       False  Southampton   yes  False  Middle Age
# 4    man        True  Southampton    no   True  Middle Age

# %%
df['binned_age']. value_counts()
# Out:
# binned_age
# Youngs        447
# Middle Age    241
# Teens          70
# Old            64
# Tollders       30
# Kids           25
# infants        14
# Name: count, dtype: int64

# %% [markdown]
# # renaming a column binned age

# %%
df.rename(columns={'binned_age':'age_group'}, inplace = True)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone   age_group
# 0    man        True  Southampton    no  False      Youngs
# 1  woman       False    Cherbourg   yes  False  Middle Age
# 2  woman       False  Southampton   yes   True      Youngs
# 3  woman       False  Southampton   yes  False  Middle Age
# 4    man        True  Southampton    no   True  Middle Age

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  891 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
#  14  age_group    891 non-null    category
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# # DATA FILETRATION

# %%
# based on column
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'age_group'],
#       dtype='object')

# %%
df_01 = df[['survived','age_group','fare','class']]

# %%
df_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   survived   891 non-null    int64
#  1   age_group  891 non-null    category
#  2   fare       891 non-null    float64
#  3   class      891 non-null    category
# dtypes: category(2), float64(1), int64(1)
# memory usage: 16.3 KB

# %%
df['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
# FILTER the data based on rows criteria
df_first=df_01[df_01['class']== 'First']

# %%
df_first['class'].value_counts()
# Out:
# class
# First     216
# Second      0
# Third       0
# Name: count, dtype: int64

# %%
#Lets select only those rows which have paid more than 200 pounds
df_200=df_01[df_01['fare'] > 71]

# %%
df_200['class'].value_counts()
# Out:
# class
# First     98
# Second     5
# Third      0
# Name: count, dtype: int64

# %%
# how two add filter
df_01[(df_01['fare'] > 70) & (df_01['class'] == 'First')].sort_values(by='fare')  #SORT minimum se maximum krenga
# ASSEND mean neche se upr jana choti value se bri value ki trf jana
# DESCEND  mean upr se neche jana bri value se chotti ki trf ana
# Out:
#      survived   age_group      fare  class
# 540         1  Middle Age   71.0000  First
# 745         0         Old   71.0000  First
# 1           1  Middle Age   71.2833  First
# 366         1         Old   75.2500  First
# 218         1  Middle Age   76.2917  First
# ..        ...         ...       ...    ...
# 438         0         Old  263.0000  First
# 27          0      Youngs  263.0000  First
# 679         1  Middle Age  512.3292  First
# 258         1  Middle Age  512.3292  First
# 737         1  Middle Age  512.3292  First
#
# [100 rows x 4 columns]
